# %%
import numpy as np
import matplotlib.pyplot as plt

Y_True = [2, 3, 5, 4, 5, 7, 9, 6, 3, 4]
Y_Pred = [1.8, 3.35, 5.13, 3.78, 5.99, 6.33, 8.95, 6.12, 2.75, 3.5]

MSE = np.square(np.subtract(Y_True, Y_Pred)).mean()
print("Mean Squared Error:", MSE)

# Plot the true values and predicted values
plt.plot(Y_True, label='True Values', marker='o')
plt.plot(Y_Pred, label='Predicted Values', marker='x')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.title('True Values vs. Predicted Values')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Mean Squared Error: 0.19862000000000005
